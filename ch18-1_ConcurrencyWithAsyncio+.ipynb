# %% [markdown]
# ## 파이썬에서 비동기 프로그래밍 시작하기
# <b> 참고자료 </b>
# https://sjquant.tistory.com/14?category=770799
#
# ### 기초
# 파이썬에서 비동기를 사용하기 위해서는 asyncio 모듈을 이용합니다. 함수앞에 async를 붙이면 코루틴을 만들 수 있습니다. 또한, 병목이 발생해서 다른 작업으로 통제권을 넘겨줄 필요가 있는 부분에서는 await를 써줍니다. 이때, await뒤에 오는 함수도 코루틴으로 작성되어 있어야 합니다. asyncio.sleep함수는 코루틴으로 구현되어 있기 때문에 비동기로 동작합니다. 따라서 time.sleep는 사용할 수 없습니다. (코루틴이 아닌 함수도 비동기에서 사용하는 법은 뒤에서 다룹니다.)
#
# 코루틴으로 태스크를 만들었다면, asyncio.get_event_loop함수를 활용해 이벤트 루프를 정의하고 run_until_complete으로 실행시킬 수 있습니다.

# %%
import asyncio
import time

import nest_asyncio
nest_asyncio.apply() # This module patches asyncio to allow nested (due to jupyter notebook)

async def sleep():
    await asyncio.sleep(5)
    
start = time.time()
loop = asyncio.get_event_loop()  # 이벤트 루프 정의
loop.run_until_complete(sleep()) # 이벤트 루프 실행
end = time.time()

print(str(end-start)+'s')
# Out:
# 5.002918243408203s

# %% [markdown]
# ### 비동기적 처리
# 비동기로 두 개 이상의 작업(코루틴)을 돌릴 때에는 asyncio.gather 함수를 이용합니다. 이때, 각 태스크들은 unpacked 형태로 넣어주어야 합니다. 즉, asyncio.gather(coroutine_1(), coroutine_2())처럼 넣어주거나 asyncio.gather(*[coroutine_1(), coroutine_2()])처럼 넣어주어야 합니다.

# %%
import asyncio
import time

import nest_asyncio
nest_asyncio.apply() # This module patches asyncio to allow nested (due to jupyter notebook)

async def coroutine_1():
    print("start coroutine 1")
    print("stop coroutine 1 for 5 sec")
    await asyncio.sleep(5)
    print("restart corountine 1")
    
async def coroutine_2():
    print("start coroutine 2")
    print("stop coroutine 2 for 5 sec")
    await asyncio.sleep(5)
    print("restart corountine 2")
    
if __name__ == '__main__':
    loop = asyncio.get_event_loop()

    start = time.time()
    # 코루틴이 복수 일 경우에는 asyncio.gather()를 먼저 이용하며, 순서대로 스케줄링 된다.
    loop.run_until_complete(asyncio.gather(coroutine_1(), coroutine_2()))
    end = time.time()

    print('time taken: {}'.format(end-start))
# Out:
# start coroutine 2
# stop coroutine 2 for 5 sec
# start coroutine 1
# stop coroutine 1 for 5 sec
# restart corountine 2
# restart corountine 1
# time taken: 5.007169961929321

# %% [markdown]
# ### 코루틴으로 작성되지 않은 함수 비동기적으로 이용하기
# 위에서 await뒤에 오는 함수 역시 코루틴으로 작성되어 있어야 비동기적인 작업을 할 수 있다고 했습니다. 파이썬의 대부분의 라이브러리들은 비동기를 고려하지 않고 만들어졌기 때문에 비동기로 이용할 수 없습니다. 하지만, 이벤트 루프의 run_in_executor함수를 이용하면 가능합니다.
#
# asyncio.get_event_loop()를 활용해서 현재 이벤트 루프를 loop라는 이름으로 받아오고, loop.run_in_executor를 사용하면 됩니다. 이 함수의 첫 번째 인자로는 concurrent.futures.Executor의 객체가 들어가고(None을 써주시면 asyncio의 내장 executor가 들어갑니다), 두 번째 인자로는 사용하고자 하는 함수, 그 이후의 인자(*args) 에는 사용하고자 하는 함수의 인자들을 써주면 됩니다.

# %%
import asyncio
import time

import nest_asyncio
nest_asyncio.apply() # This module patches asyncio to allow nested (due to jupyter notebook)

async def coroutine_1():
    print("start coroutine 1")
    print("stop coroutine 1 for 5 sec")
    
    loop = asyncio.get_event_loop()
    await loop.run_in_executor(None, time.sleep, 5)
    
    print("restart corountine 1")
    
async def coroutine_2():
    print("start coroutine 2")
    print("stop coroutine 2 for 4 sec")
    
    loop = asyncio.get_event_loop()
    await loop.run_in_executor(None, time.sleep, 4)

    print("restart corountine 2")
    
if __name__ == '__main__':
    loop = asyncio.get_event_loop()
    
    start = time.time()
    loop.run_until_complete(asyncio.gather(coroutine_1(), coroutine_2()))
    end = time.time()
    
    print('time taken: {}'.format(end-start))
# Out:
# start coroutine 2
# stop coroutine 2 for 4 sec
# start coroutine 1
# stop coroutine 1 for 5 sec
# restart corountine 2
# restart corountine 1
# time taken: 5.0084052085876465

# %% [markdown]
# ### run_in_executor 과 asyncio.sleep를 이용하여 성능 비교하기
# asyncio.sleep을 사용한 것과 거의 유사한 결과를 볼 수 있습니다. 원리는 무엇일까요? 사실 이것은 비동기적 처리처럼 보이지만 실제로는 쓰레딩을 이용한 것이라고 할 수 있습니다. 첫번째 글에서 언급했던 멀티쓰레드기억나시나요? 비동기적 처리보다는 비효율적이었지만 작업이 완료되길 기다리고 다른 작업을 시작하는 것보다는 빠르게 작업을 처리할 수 있었습니다.
#
# 하지만, 쓰레딩을 이용했을 때는 비용도 만만치 않았습니다. 파이썬에서는 GIL 때문에 쓰레드들이 동시에 작업이 불가능하기 때문에, 다른 쓰레드를 호출하는데 걸리는 시간을 낭비하게 됩니다. (컨텍스트 스위칭의 비용)

# %%
import asyncio
import time
from concurrent.futures import ThreadPoolExecutor

async def sleep(executor=None):
    loop = asyncio.get_event_loop()
    await loop.run_in_executor(executor, time.sleep, 1)

async def main():

    # max_workers에 따라서 실행시간이 달라지는 것을 확인할 수 있다.
    # (하지만 workers가 많아질수록 컨텍스트 스위칭 비용도 커진다.)
    # None으로 하는 경우는 디폴트로 설정한 workers수가 작아서 인지 훨씬 더 오래걸린다.

    executor = ThreadPoolExecutor(max_workers=10000)

    # asyncio.ensure_future함수는 태스크를 현재 실행하지 않고,
    # 이벤트 루프가 실행될 때 실행할 것을 보증해주는 함수
    futures = [asyncio.ensure_future(sleep(executor)) for i in range(10000)]
    await asyncio.gather(*futures)

if __name__ == "__main__":
    start = time.time()
    # python 3.7부터는 이벤트 루프를 따로 명시적으로 지정하지 않고, asyncio.run으로 돌릴 수 있다.
    asyncio.run(main())
    end = time.time()
    print('{}'.format(end-start))
# Out:
# 78.71488571166992

# %%
import asyncio
import time

async def sleep():
    await asyncio.sleep(1)

async def main():
    # asyncio.sleep은 아무리 많아져도 비동기적으로 잘 돌아간다.
    futures = [asyncio.ensure_future(sleep()) for i in range(10000)]
    await asyncio.gather(*futures)

if __name__ == "__main__":
    start = time.time()
    asyncio.run(main())
    end = time.time()
    print('{}'.format(end-start))
# Out:
# 1.595499038696289

# %% [markdown]
# ### 비동기 프로그래밍 사례
# #### 동기적 방식
# 비동기를 사용하면 네트워크 IO의 지연 때문에 낭비되는 시간을 줄일 수 있습니다. 온라인 사전사이트(네이버)에서 단어들의 의미를 크롤링하는 코드를 작성한다고 가정해봅시다. 동기적인 방식을 사용한다면 아래와 같이 코드를 작성할 수 있습니다.

# %%
import requests
import time
from bs4 import BeautifulSoup

def get_text_from_url(url):
    print("Send request to {url}".format(url=url))
    res = requests.get(url, headers={'uesr-agent': 'Mozilla/5.0'})
    print("Get request from {url}".format(url=url))
    text = BeautifulSoup(res.text, 'html.parser').text
    return text

if __name__ == '__main__':
    start = time.time()
    
    base_url = 'https://endic.naver.com/search.nhn?sLn=kr&dicQuery={keyword}&query={keyword}&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N'
    keywords = ['apple', 'banana', 'call', 'feel',
                'hello', 'bye', 'like', 'love', 'environmental',
                'buzz', 'ambition', 'determine']

    urls = [base_url.format(keyword=keyword) for keyword in keywords]
    for url in urls:
        text = get_text_from_url(url)
        print("=" * 150)            
        print(text[8100:9000].strip())
        
    end = time.time()
    print("time taken: {}".format(end-start))
# Out:
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=apple&query=apple&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=apple&query=apple&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# apple tree
#
#
#
#
#
#
# 신 사과
#
#
#
#
#
#
#
#
#
# a sour apple
#
#
#
#
#
#
# 애플 파이
#
#
#
#
#
#
#
#
#
# an apple pie
#
#
#
#
#
# 본문 더보기
#
#
#
# (17,812건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# People seem to be a lot like people in the Big Apple.
# 듣기
# 출처:능률교육
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 사람들이 뉴욕 사람들과 비슷한 점이 많은 것 같아.
#
#
# 상세
#
#
# [일반]
# The apple tree yields well[poorly] this year.
# 듣기
# 출처:동아 출판
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 금년은 사과의 수확이 좋다[나쁘다].
#
#
# 상세
#
#
# [일반]
# There is an apple tree near my house.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 집 주변에 사과 나무가 한 그루 있어요.
#
#
# 상세
#
#
# [일반]
# This apple tastes a bit sour.
# 듣기
# 출처:동아 출판
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 이 사과는 새금하다
#
#
# 상세
#
#
# [일반]
# His room is always in apple-pie order.
# 듣기
# 출처:동아 출판
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 그의 방은 언제나 깨끗이 정돈되어 있다
#
#
# 상세
#
# 예문 더보기
#
#
#
#
#
#
# VLIVE 자막(575건)
#
# VLIVE 자막 도움말
#
# 		                        전세계 V팬들이 직접 자막을 번역한 것으로 다소 정확하지 않을 수 있습니다.
# 		                        VLIVE 도움말 닫기
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=banana&query=banana&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=banana&query=banana&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# 바나나 껍질
#
#
#
#
#
#
#
#
#
# a banana peel
#
#
#
#
#
#
# 바나나 껍질을 까다
#
#
#
#
#
#
#
#
#
# peel a banana
#
#
#
#
#
#
# 바나나 껍질을 벗기다
#
#
#
#
#
#
#
#
#
# peel a banana
#
#
#
#
#
# 본문 더보기
#
#
#
# (4,895건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# She's slicing a banana into a bowl.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 여자가 바나나를 얇게 잘라 접시에 담고 있다.
#
#
# 상세
#
#
# [일반]
# He slipped on a banana skin.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 그는 바나나 껍질을 밟아서 미끄러졌다.
#
#
# 상세
#
#
# [일반]
# This year, however, banana prices have skyrocketed.
# 듣기
# 출처:능률교육
#
#
#
# 현대
# 해당없음
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 하지만 올해, 바나나 값이 급등했다.
#
#
# 상세
#
#
# [일반]
# When he trod on a banana skin he slipped down.
# 듣기
# 출처:잉글리시히든카드
#
#
#
# 현대
# 해당없음
# 초급
#
#
#
#
#
#
#
#
# 그는 바나나 껍질을 밟았을 때 미끌어 넘어졌다.
#
#
# 상세
#
#
# [일반]
# She's feeding a banana to a monkey.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 여자가 원숭이에게 바나나를 먹이고 있다.
#
#
# 상세
#
# 예문 더보기
#
#
#
#
#
#
# VLIVE 자막(482건)
#
# VLIVE 자막 도움말
#
# 		                        전세계 V팬들이 직접 자막을 번역한 것으로 다소 정확하지 않을 수 있습니다.
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=call&query=call&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=call&query=call&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# :
#
# 		                        [명사] (특히 국가 간 경기 출전을 위한) 부름
#
#
#
# 중고등학교 교과서 단어
#
#
#
#
# 단어/숙어 더보기
#
#
#
#
# (2,995건)
#
#
#
#
# 연락
#               			連絡
#
#
#
#
#
#
#
#
#
#
# contact; (전화) call, contact, get[keep] in touch (with); (전화하다) call
#
#
# 연락하고 지냅시다
#
#
# Let's keep in touch.
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 전화1
#               			電話
#
#
#
#
#
#
#
#
#
#
#
#
#
# phone call, (telephone) call; (전화기) telephone, phone, call (up), phone, (Brit) ring
#
#
# 전화를 걸다
#
#
# make a (phone) call
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 요청
#               			要請
#
#
#
#
#
#
#
#
#
#
# [명사] request, demand, call; (비용을) claim, [동사] request, demand, call for, ask, call (up)on
#
#
# 요청을 수락하다
#
#
# grant sb's request
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 부르다1
#
#
#
#
#
#
#
#
#
# (소리를 치다) call (out)
#
#
# 이름을 부르다
#
#
# call sb's name
#
# 예문 TTS 발음듣기
#
#
#
#
# 7 개 뜻 더보기
# 		                    	 :
#
# (소리를 치다) call (out)
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=feel&query=feel&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=feel&query=feel&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# :
#
# (감각·감정 등을) feel, experience
#
#
#
#
#
#
# 만지다
#
#
#
#
#
#
#
#
#
# (손으로) touch; (무엇인지 알아내기 위해) feel
#
#
# 어깨를 만지다
#
#
# touch sb on the shoulder
#
# 예문 TTS 발음듣기
#
#
#
#
# 3 개 뜻 더보기
# 		                    	 :
#
# (손으로) touch; (무엇인지 알아내기 위해) feel
#
#
#
#
#
#
# 실감
#               			實感
#
#
#
#
#
#
#
#
#
#
# feel, realize
#
#
# 실감 나는
#
#
# realistic
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 체감
#               			體感
#
#
#
#
#
#
#
#
#
#
# feel
#
#
# 온도 변화를 체감하다
#
#
# feel the temperature change
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 감촉
#               			感觸
#
#
#
#
#
#
#
#
#
#
# touch, feel
#
#
# 감촉이 좋다
#
#
# feel good[pleasant]
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
# 본문 더보기
#
#
#
# (253,107건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# On stage I feel very intense power.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 무대 위에서 강력한 힘을 느낍니다.
#
#
# 상세
#
#
# [일반]
# I feel my way around achieving my goal.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 내 목표를 이루기 위해 나는
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=hello&query=hello&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=hello&query=hello&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# TTS 발음듣기
#
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# (전화를 하거나 받을 때) hello
#
#
#
#
#
#
# 안녕, 오늘 기분이 어때?
#
#
#
#
#
#
#
#
#
# Hello, how are you today?
#
#
#
#
#
#
# 안녕하세요, 예약을 하려 합니다.
#
#
#
#
#
#
#
#
#
# Hello, l'd like to make a reservation, please.
#
#
#
#
#
#
# 여보세요, 거기가 375-2922번입니까?
#
#
#
#
#
#
#
#
#
# Hello, Is this 375-2922?
#
#
#
#
#
#
# 여보세요, 로버트와 통화하고 싶습니다.
#
#
#
#
#
#
#
#
#
# Hello, may I speak to Robert, please?
#
#
#
#
#
# 본문 더보기
#
#
#
# (6,993건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# And in Alaska, people rub noses to say hello!
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 그리고 알래스카에서, 사람들은 코를 비비며 인사를 한다!
#
#
# 상세
#
#
# [일반]
# Hello. I'd like Customer Service, please.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 여보세요. 고객 서비스부 부탁해요.
#
#
# 상세
#
#
# [일반]
# Hello! Attorney's office, this is Joan speaking.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 여보세요. 변호사 사무실의 존입니다.
#
#
# 상세
#
#
# [일반]
# Hello, I need to talk to someone about a billing problem.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 안녕하세요, 요금
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=bye&query=bye&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=bye&query=bye&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# (인사) (만났을 때) hello, (informal) hi; (헤어질 때) good-bye, (informal) bye
#
#
# 안녕, 나중에 보자
#
#
# See you later.
#
# 예문 TTS 발음듣기
#
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# (인사) (만났을 때) hello, (informal) hi; (헤어질 때) good-bye, (informal) bye
#
#
#
#
#
#
# 안녕히 계세요/가세요.
#
#
#
#
#
#
#
#
#
# Good-bye.
#
#
#
# 9 개 뜻 더보기
# 		                    	 :
#
# Good-bye.
#
#
#
#
#
#
# 크리켓 바이
#
#
#
#
#
#
#
#
#
# (스포츠)
# bye
#
#
#
#
#
#
# 테니스 바이
#
#
#
#
#
#
#
#
#
# (스포츠)
# bye
#
#
#
#
#
#
# 작별 인사를 나누다
#
#
#
#
#
#
#
#
#
# say goodbye
#
#
#
# 3 개 뜻 더보기
# 		                    	 :
#
# say goodbye
#
#
#
#
#
# 본문 더보기
#
#
#
# (6,375건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# It’s not that I wanna say goodbye.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 헤어지고 싶다는 말을 하려는건 아니예요.
#
#
# 상세
#
#
# [일반]
# It is always so hard to say goodbye to friends.
# 듣기
# 출처:능률교육
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 친구들이랑 헤어지는 게 항상 너무 힘들어.
#
#
# 상세
#
#
# [일반]
# Look me up when you're in town. Bye.
# 듣기
# 출처:능률교육
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 시내에 오시면 들러요. 안녕.
#
#
# 상세
#
#
# [일반]
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=like&query=like&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=like&query=like&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ,
#
# 		                        [전치사] …와 같이, …처럼
# ,
#
# 		                        [접속사] …(하)듯이, …같이(as)
# 		                        ,
#
# 		                        [명사] [the ~, one’s ~] 비슷한 사람[것]; 같은 사람[것]; 동류; 필적하는[동등한] 것 ((of))
# 		                        ,
#
# 		                        [감탄사] [대화의 시작, 연결 등 특별한 의미 없이] 저-, 있잖아, 음- ((허물없는 회화에서 무의식적·습관적으로 사용됨))
#
#
#
# 중고등학교 교과서 단어골프
#
#
#
#
#
# like2
#
# 					미국·영국
#
# 					[láik]
#
# 성우 발음듣기
#
# 					영국식
#
#
#
# 성우 발음듣기
#
#
#
#
#
#
#
#
#
#
# [타동사]
# <물건·사람을> 좋아하다
#
#
# I like it best of all my suits.
#
# 예문 TTS 발음듣기
#
#
#
# 나는 내 양복 중에서 그것을 가장 좋아한다.
#
#
#
# 8 개 뜻 더보기
# 		                    	 :
#
# 		                        [타동사] (…하는 것을) 좋아하다
# 		                        ,
#
# 		                        [자동사] 마음에 들다, 마음이 내키다(be pleased)
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=love&query=love&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=love&query=love&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# u a cuddle when you cry and give you advice when you n...
#
#
#
#
#
#
# love-in
#
# 					미국식
#
#
#
# 성우 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# [명사]
# (구식)
# 러브인(1960년대에 히피들이 주로 갖던 사랑의 집회)
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# 		                        [명사] (사람들이 진심이 아니면서) 서로 다정하게 굴기
#
#
#
# 중고등학교 교과서 단어
#
#
#
#
# 단어/숙어 더보기
#
#
#
#
# (2,143건)
#
#
#
#
# 사랑
#
#
#
#
#
#
#
#
#
# [명사] love, [동사] love, cherish
#
#
# 사랑에 빠지다
#
#
# fall in love (with)
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 러브
#
#
#
#
#
#
#
#
#
# (사랑) love, (테니스에서 무득점) love,
#
#
#
#
#
#
# 좋아하다
#
#
#
#
#
#
#
#
#
# (즐기다, 선호하다) like, love, be fond of, enjoy (doing),  go for; (사람을) care for
#
#
# 단것을 좋아하다
#
#
# like sweet things
#
# 예문 TTS 발음듣기
#
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# (즐기다, 선호하다) like, love, be fond of, enjoy (doing),  go for; (사람을) care for
#
#
#
#
#
#
# 귀여워하다
#
#
#
#
#
#
#
#
#
# love, adore, dote on
#
#
# 자기 자식처럼 귀여워하다
#
#
# love sb like one's own child
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 애정
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=environmental&query=environmental&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=environmental&query=environmental&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# TTS 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# 환경에 해독을 끼치다
#
# 중고등학교 교과서 단어
#
#
#
#
# 단어/숙어 더보기
#
#
#
#
# (890건)
#
#
#
#
# environ.
#
# 					미국식
#
#
#
# 성우 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# environment; environmental; environmentalism
#
#
#
#
#
#
# Env.
#
# 					미국식
#
#
#
# TTS 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# environmental; Envoy.
#
#
#
#
#
#
# 환경권
#
#
#
#
#
#
#
#
#
# environmental rights
#
#
# 환경권을 침해하다
#
#
# violate sb's environmental rights
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 환경문제
#
#
#
#
#
#
#
#
#
# environmental problem[issue]
#
#
# 환경문제에 관한 관심이 커지고 있다
#
#
# More people are becoming aware of[interested in] environmental issues.
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 환경 과학
#
#
#
#
#
#
#
#
#
# environmental science
#
#
#
#
#
# 본문 더보기
#
#
#
# (47,758건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# The Body Shop is well-known for its environmental concerns.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# ‘바디샵’은 환경을 배려하는 기업으로 정평이 났습니다.
#
#
# 상세
#
#
# [IT/과학]
# Value o
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=buzz&query=buzz&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=buzz&query=buzz&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# (소문) rumor; (확실치 않은) hearsay, (informal) buzz
#
#
# 그가 학교에 장학금을 기증했다는 후문이 돌았다
#
#
# There was a rumor that he had donated scholarship to the school.
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 설2
#               			說
#
#
#
#
#
#
#
#
#
#
# (소문) rumor, (informal) buzz
#
#
# 그 정치인이 범죄 집단과 연관되어 있다는 설이 있다
#
#
# There is a rumor[buzz] that the politician has links with a criminal organization.
#
# 예문 TTS 발음듣기
#
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# (소문) rumor, (informal) buzz
#
#
#
#
#
# 본문 더보기
#
#
#
# (4,633건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# He didn't have the guts to buzz her.
# 듣기
# 출처:능률교육
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 그는 차마 용기가 안나서 그 여자한테 전화를 못했다.
#
#
# 상세
#
#
# [일반]
# The buzz word right now is Bollywood.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 요즘 유행하는 말은 할리우드가 아닌 발리우드라고 합니다.
#
#
# 상세
#
#
# [일반]
# The drug addicted man had a buzz on.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 중급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 마약중독자는 거나하게 취해있었다.
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=ambition&query=ambition&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=ambition&query=ambition&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ambition, aspiration
#
#
# 야망을 이루다
#
#
# achieve[fulfill; realize] one's ambition
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 욕망
#               			慾望
#
#
#
#
#
#
#
#
#
#
# desire (for / to do), appetite (for), craving (for); (야망) ambition
#
#
# 욕망을 억누르다
#
#
# suppress[curb; subdue] one's desire
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 야심
#               			野心
#
#
#
#
#
#
#
#
#
#
# ambition, aspiration
#
#
# 야심 찬 포부를 내비치다
#
#
# show an ambitious goal
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 야욕
#               			野慾
#
#
#
#
#
#
#
#
#
#
# ambition
#
#
# 북한은 아직도 적화통일의 야욕을 버리지 못하고 있다
#
#
# North Korea still hasn't given up the ambition of a forceful unification.
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 포부
#               			抱負
#
#
#
#
#
#
#
#
#
#
# (희망) aspiration(s), hope(s); (계획) plan; (야망) ambition
#
#
# 포부를 말하다
#
#
# speak of one's aspiration(s)
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
# 본문 더보기
#
#
#
# (11,614건
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=determine&query=determine&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=determine&query=determine&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# 역기 결과 내용
# |파파고(번역)
#
#
#
#
#
#
#
#
# determine the ranking
#
# 					미국식
#
#
#
# TTS 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# 순위를 매기다
#
# 중고등학교 교과서 단어
#
#
#
#
# 단어/숙어 더보기
#
#
#
#
# (2,192건)
#
#
#
#
# 정하다
#               			定―
#
#
#
#
#
#
#
#
#
#
# (결정하다) decide, determine; (날짜·장소 등을) fix, set, (formal) appoint; (여럿 중에서 고르다) choose (from/between)
#
#
# 규칙을 정하다
#
#
# make[set up] rules
#
# 예문 TTS 발음듣기
#
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# (결정하다) decide, determine; (날짜·장소 등을) fix, set, (formal) appoint; (여럿 중에서 고르다) choose (from/between)
#
#
#
#
#
#
# 확정
#               			確定
#
#
#
#
#
#
#
#
#
#
# [동사] decide (on/upon), determine, settle, set, fix, confirm, finalize
#
#
# 확정금리로 대출을 받다
#
#
# get[take out] a loan at a fixed interest rate
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 결심1
#               			決心
#
#
#
#
#
#
#
#
#
#
# [명사] (결정) decision, resolution, determination,
# time taken: 3.4746909141540527

# %% [markdown]
# #### 비동기적 방식 (Asyncio + requests)
# 이번에는 비동기적으로 코드를 작성해봅시다. requests는 비동기적으로 작성되지 않았기 때문에 loop.run_in_executor를 통해 쓰레드를 만드는 방식을 사용합니다.

# %%
import requests
import time
import asyncio
from functools import partial
from bs4 import BeautifulSoup


async def get_text_from_url(url):  # 코루틴 정의
    print("Send request to {url}".format(url=url))
    loop = asyncio.get_event_loop()

    # loop.run_in_executor는 kwargs(keyword arguments)를 사용할 수 없기 때문에 functools.partial을 활용
    request = partial(requests.get, url, headers={'user-agent': 'Mozilla/5.0'})
    # ascyncio의 디폴트 쓰레드풀을 사용할 경우 첫번째 인자로 None
    # 직접 쓰레드풀을 만들 경우 concurrent.futures.threadpoolexecutor 사용
    res = await loop.run_in_executor(None, request)
    print("Get request from {url}".format(url=url))
    text = BeautifulSoup(res.text, 'html.parser').text
    print("=" * 150)    
    print(text[8100:9000].strip())


async def main():
    base_url = 'https://endic.naver.com/search.nhn?sLn=kr&dicQuery={keyword}&query={keyword}&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N'
    keywords = ['apple', 'banana', 'call', 'feel',
                'hello', 'bye', 'like', 'love', 'environmental',
                'buzz', 'ambition', 'determine']

    # 아직 실행된 것이 아니라, 실행할 것을 계획하는 단계
    futures = [asyncio.ensure_future(get_text_from_url(
        base_url.format(keyword=keyword))) for keyword in keywords]

    await asyncio.gather(*futures)

if __name__ == "__main__":
    start = time.time()
    loop = asyncio.get_event_loop()
    loop.run_until_complete(main())
    end = time.time()
    print("time taken: {}".format(end-start))
# Out:
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=apple&query=apple&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=banana&query=banana&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=call&query=call&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=feel&query=feel&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=hello&query=hello&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=bye&query=bye&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=like&query=like&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=love&query=love&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=environmental&query=environmental&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=buzz&query=buzz&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=ambition&query=ambition&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=determine&query=determine&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=apple&query=apple&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# apple tree
#
#
#
#
#
#
# 신 사과
#
#
#
#
#
#
#
#
#
# a sour apple
#
#
#
#
#
#
# 애플 파이
#
#
#
#
#
#
#
#
#
# an apple pie
#
#
#
#
#
# 본문 더보기
#
#
#
# (17,812건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# People seem to be a lot like people in the Big Apple.
# 듣기
# 출처:능률교육
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 사람들이 뉴욕 사람들과 비슷한 점이 많은 것 같아.
#
#
# 상세
#
#
# [일반]
# The apple tree yields well[poorly] this year.
# 듣기
# 출처:동아 출판
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 금년은 사과의 수확이 좋다[나쁘다].
#
#
# 상세
#
#
# [일반]
# There is an apple tree near my house.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 집 주변에 사과 나무가 한 그루 있어요.
#
#
# 상세
#
#
# [일반]
# This apple tastes a bit sour.
# 듣기
# 출처:동아 출판
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 이 사과는 새금하다
#
#
# 상세
#
#
# [일반]
# His room is always in apple-pie order.
# 듣기
# 출처:동아 출판
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 그의 방은 언제나 깨끗이 정돈되어 있다
#
#
# 상세
#
# 예문 더보기
#
#
#
#
#
#
# VLIVE 자막(575건)
#
# VLIVE 자막 도움말
#
# 		                        전세계 V팬들이 직접 자막을 번역한 것으로 다소 정확하지 않을 수 있습니다.
# 		                        VLIVE 도움말 닫기
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=feel&query=feel&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# :
#
# (감각·감정 등을) feel, experience
#
#
#
#
#
#
# 만지다
#
#
#
#
#
#
#
#
#
# (손으로) touch; (무엇인지 알아내기 위해) feel
#
#
# 어깨를 만지다
#
#
# touch sb on the shoulder
#
# 예문 TTS 발음듣기
#
#
#
#
# 3 개 뜻 더보기
# 		                    	 :
#
# (손으로) touch; (무엇인지 알아내기 위해) feel
#
#
#
#
#
#
# 실감
#               			實感
#
#
#
#
#
#
#
#
#
#
# feel, realize
#
#
# 실감 나는
#
#
# realistic
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 체감
#               			體感
#
#
#
#
#
#
#
#
#
#
# feel
#
#
# 온도 변화를 체감하다
#
#
# feel the temperature change
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 감촉
#               			感觸
#
#
#
#
#
#
#
#
#
#
# touch, feel
#
#
# 감촉이 좋다
#
#
# feel good[pleasant]
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
# 본문 더보기
#
#
#
# (253,107건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# On stage I feel very intense power.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 무대 위에서 강력한 힘을 느낍니다.
#
#
# 상세
#
#
# [일반]
# I feel my way around achieving my goal.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 내 목표를 이루기 위해 나는
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=call&query=call&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# :
#
# 		                        [명사] (특히 국가 간 경기 출전을 위한) 부름
#
#
#
# 중고등학교 교과서 단어
#
#
#
#
# 단어/숙어 더보기
#
#
#
#
# (2,995건)
#
#
#
#
# 연락
#               			連絡
#
#
#
#
#
#
#
#
#
#
# contact; (전화) call, contact, get[keep] in touch (with); (전화하다) call
#
#
# 연락하고 지냅시다
#
#
# Let's keep in touch.
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 전화1
#               			電話
#
#
#
#
#
#
#
#
#
#
#
#
#
# phone call, (telephone) call; (전화기) telephone, phone, call (up), phone, (Brit) ring
#
#
# 전화를 걸다
#
#
# make a (phone) call
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 요청
#               			要請
#
#
#
#
#
#
#
#
#
#
# [명사] request, demand, call; (비용을) claim, [동사] request, demand, call for, ask, call (up)on
#
#
# 요청을 수락하다
#
#
# grant sb's request
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 부르다1
#
#
#
#
#
#
#
#
#
# (소리를 치다) call (out)
#
#
# 이름을 부르다
#
#
# call sb's name
#
# 예문 TTS 발음듣기
#
#
#
#
# 7 개 뜻 더보기
# 		                    	 :
#
# (소리를 치다) call (out)
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=bye&query=bye&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# (인사) (만났을 때) hello, (informal) hi; (헤어질 때) good-bye, (informal) bye
#
#
# 안녕, 나중에 보자
#
#
# See you later.
#
# 예문 TTS 발음듣기
#
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# (인사) (만났을 때) hello, (informal) hi; (헤어질 때) good-bye, (informal) bye
#
#
#
#
#
#
# 안녕히 계세요/가세요.
#
#
#
#
#
#
#
#
#
# Good-bye.
#
#
#
# 9 개 뜻 더보기
# 		                    	 :
#
# Good-bye.
#
#
#
#
#
#
# 크리켓 바이
#
#
#
#
#
#
#
#
#
# (스포츠)
# bye
#
#
#
#
#
#
# 테니스 바이
#
#
#
#
#
#
#
#
#
# (스포츠)
# bye
#
#
#
#
#
#
# 작별 인사를 나누다
#
#
#
#
#
#
#
#
#
# say goodbye
#
#
#
# 3 개 뜻 더보기
# 		                    	 :
#
# say goodbye
#
#
#
#
#
# 본문 더보기
#
#
#
# (6,375건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# It’s not that I wanna say goodbye.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 헤어지고 싶다는 말을 하려는건 아니예요.
#
#
# 상세
#
#
# [일반]
# It is always so hard to say goodbye to friends.
# 듣기
# 출처:능률교육
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 친구들이랑 헤어지는 게 항상 너무 힘들어.
#
#
# 상세
#
#
# [일반]
# Look me up when you're in town. Bye.
# 듣기
# 출처:능률교육
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 시내에 오시면 들러요. 안녕.
#
#
# 상세
#
#
# [일반]
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=hello&query=hello&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# TTS 발음듣기
#
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# (전화를 하거나 받을 때) hello
#
#
#
#
#
#
# 안녕, 오늘 기분이 어때?
#
#
#
#
#
#
#
#
#
# Hello, how are you today?
#
#
#
#
#
#
# 안녕하세요, 예약을 하려 합니다.
#
#
#
#
#
#
#
#
#
# Hello, l'd like to make a reservation, please.
#
#
#
#
#
#
# 여보세요, 거기가 375-2922번입니까?
#
#
#
#
#
#
#
#
#
# Hello, Is this 375-2922?
#
#
#
#
#
#
# 여보세요, 로버트와 통화하고 싶습니다.
#
#
#
#
#
#
#
#
#
# Hello, may I speak to Robert, please?
#
#
#
#
#
# 본문 더보기
#
#
#
# (6,993건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# And in Alaska, people rub noses to say hello!
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 그리고 알래스카에서, 사람들은 코를 비비며 인사를 한다!
#
#
# 상세
#
#
# [일반]
# Hello. I'd like Customer Service, please.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 여보세요. 고객 서비스부 부탁해요.
#
#
# 상세
#
#
# [일반]
# Hello! Attorney's office, this is Joan speaking.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 여보세요. 변호사 사무실의 존입니다.
#
#
# 상세
#
#
# [일반]
# Hello, I need to talk to someone about a billing problem.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 안녕하세요, 요금
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=banana&query=banana&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# 바나나 껍질
#
#
#
#
#
#
#
#
#
# a banana peel
#
#
#
#
#
#
# 바나나 껍질을 까다
#
#
#
#
#
#
#
#
#
# peel a banana
#
#
#
#
#
#
# 바나나 껍질을 벗기다
#
#
#
#
#
#
#
#
#
# peel a banana
#
#
#
#
#
# 본문 더보기
#
#
#
# (4,895건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# She's slicing a banana into a bowl.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 여자가 바나나를 얇게 잘라 접시에 담고 있다.
#
#
# 상세
#
#
# [일반]
# He slipped on a banana skin.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 그는 바나나 껍질을 밟아서 미끄러졌다.
#
#
# 상세
#
#
# [일반]
# This year, however, banana prices have skyrocketed.
# 듣기
# 출처:능률교육
#
#
#
# 현대
# 해당없음
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 하지만 올해, 바나나 값이 급등했다.
#
#
# 상세
#
#
# [일반]
# When he trod on a banana skin he slipped down.
# 듣기
# 출처:잉글리시히든카드
#
#
#
# 현대
# 해당없음
# 초급
#
#
#
#
#
#
#
#
# 그는 바나나 껍질을 밟았을 때 미끌어 넘어졌다.
#
#
# 상세
#
#
# [일반]
# She's feeding a banana to a monkey.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 여자가 원숭이에게 바나나를 먹이고 있다.
#
#
# 상세
#
# 예문 더보기
#
#
#
#
#
#
# VLIVE 자막(482건)
#
# VLIVE 자막 도움말
#
# 		                        전세계 V팬들이 직접 자막을 번역한 것으로 다소 정확하지 않을 수 있습니다.
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=like&query=like&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ,
#
# 		                        [전치사] …와 같이, …처럼
# ,
#
# 		                        [접속사] …(하)듯이, …같이(as)
# 		                        ,
#
# 		                        [명사] [the ~, one’s ~] 비슷한 사람[것]; 같은 사람[것]; 동류; 필적하는[동등한] 것 ((of))
# 		                        ,
#
# 		                        [감탄사] [대화의 시작, 연결 등 특별한 의미 없이] 저-, 있잖아, 음- ((허물없는 회화에서 무의식적·습관적으로 사용됨))
#
#
#
# 중고등학교 교과서 단어골프
#
#
#
#
#
# like2
#
# 					미국·영국
#
# 					[láik]
#
# 성우 발음듣기
#
# 					영국식
#
#
#
# 성우 발음듣기
#
#
#
#
#
#
#
#
#
#
# [타동사]
# <물건·사람을> 좋아하다
#
#
# I like it best of all my suits.
#
# 예문 TTS 발음듣기
#
#
#
# 나는 내 양복 중에서 그것을 가장 좋아한다.
#
#
#
# 8 개 뜻 더보기
# 		                    	 :
#
# 		                        [타동사] (…하는 것을) 좋아하다
# 		                        ,
#
# 		                        [자동사] 마음에 들다, 마음이 내키다(be pleased)
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=environmental&query=environmental&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# TTS 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# 환경에 해독을 끼치다
#
# 중고등학교 교과서 단어
#
#
#
#
# 단어/숙어 더보기
#
#
#
#
# (890건)
#
#
#
#
# environ.
#
# 					미국식
#
#
#
# 성우 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# environment; environmental; environmentalism
#
#
#
#
#
#
# Env.
#
# 					미국식
#
#
#
# TTS 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# environmental; Envoy.
#
#
#
#
#
#
# 환경권
#
#
#
#
#
#
#
#
#
# environmental rights
#
#
# 환경권을 침해하다
#
#
# violate sb's environmental rights
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 환경문제
#
#
#
#
#
#
#
#
#
# environmental problem[issue]
#
#
# 환경문제에 관한 관심이 커지고 있다
#
#
# More people are becoming aware of[interested in] environmental issues.
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 환경 과학
#
#
#
#
#
#
#
#
#
# environmental science
#
#
#
#
#
# 본문 더보기
#
#
#
# (47,758건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# The Body Shop is well-known for its environmental concerns.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# ‘바디샵’은 환경을 배려하는 기업으로 정평이 났습니다.
#
#
# 상세
#
#
# [IT/과학]
# Value o
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=buzz&query=buzz&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# (소문) rumor; (확실치 않은) hearsay, (informal) buzz
#
#
# 그가 학교에 장학금을 기증했다는 후문이 돌았다
#
#
# There was a rumor that he had donated scholarship to the school.
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 설2
#               			說
#
#
#
#
#
#
#
#
#
#
# (소문) rumor, (informal) buzz
#
#
# 그 정치인이 범죄 집단과 연관되어 있다는 설이 있다
#
#
# There is a rumor[buzz] that the politician has links with a criminal organization.
#
# 예문 TTS 발음듣기
#
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# (소문) rumor, (informal) buzz
#
#
#
#
#
# 본문 더보기
#
#
#
# (4,633건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# He didn't have the guts to buzz her.
# 듣기
# 출처:능률교육
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 그는 차마 용기가 안나서 그 여자한테 전화를 못했다.
#
#
# 상세
#
#
# [일반]
# The buzz word right now is Bollywood.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 초급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 요즘 유행하는 말은 할리우드가 아닌 발리우드라고 합니다.
#
#
# 상세
#
#
# [일반]
# The drug addicted man had a buzz on.
# 듣기
# 출처:YBM
#
#
#
# 현대
# 미국
# 중급
# 예문 출처 페이지로이동
#
#
#
#
#
#
#
#
# 마약중독자는 거나하게 취해있었다.
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=ambition&query=ambition&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ambition, aspiration
#
#
# 야망을 이루다
#
#
# achieve[fulfill; realize] one's ambition
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 욕망
#               			慾望
#
#
#
#
#
#
#
#
#
#
# desire (for / to do), appetite (for), craving (for); (야망) ambition
#
#
# 욕망을 억누르다
#
#
# suppress[curb; subdue] one's desire
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 야심
#               			野心
#
#
#
#
#
#
#
#
#
#
# ambition, aspiration
#
#
# 야심 찬 포부를 내비치다
#
#
# show an ambitious goal
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 야욕
#               			野慾
#
#
#
#
#
#
#
#
#
#
# ambition
#
#
# 북한은 아직도 적화통일의 야욕을 버리지 못하고 있다
#
#
# North Korea still hasn't given up the ambition of a forceful unification.
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 포부
#               			抱負
#
#
#
#
#
#
#
#
#
#
# (희망) aspiration(s), hope(s); (계획) plan; (야망) ambition
#
#
# 포부를 말하다
#
#
# speak of one's aspiration(s)
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
# 본문 더보기
#
#
#
# (11,614건
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=love&query=love&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# u a cuddle when you cry and give you advice when you n...
#
#
#
#
#
#
# love-in
#
# 					미국식
#
#
#
# 성우 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# [명사]
# (구식)
# 러브인(1960년대에 히피들이 주로 갖던 사랑의 집회)
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# 		                        [명사] (사람들이 진심이 아니면서) 서로 다정하게 굴기
#
#
#
# 중고등학교 교과서 단어
#
#
#
#
# 단어/숙어 더보기
#
#
#
#
# (2,143건)
#
#
#
#
# 사랑
#
#
#
#
#
#
#
#
#
# [명사] love, [동사] love, cherish
#
#
# 사랑에 빠지다
#
#
# fall in love (with)
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 러브
#
#
#
#
#
#
#
#
#
# (사랑) love, (테니스에서 무득점) love,
#
#
#
#
#
#
# 좋아하다
#
#
#
#
#
#
#
#
#
# (즐기다, 선호하다) like, love, be fond of, enjoy (doing),  go for; (사람을) care for
#
#
# 단것을 좋아하다
#
#
# like sweet things
#
# 예문 TTS 발음듣기
#
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# (즐기다, 선호하다) like, love, be fond of, enjoy (doing),  go for; (사람을) care for
#
#
#
#
#
#
# 귀여워하다
#
#
#
#
#
#
#
#
#
# love, adore, dote on
#
#
# 자기 자식처럼 귀여워하다
#
#
# love sb like one's own child
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 애정
# Get request from https://endic.naver.com/search.nhn?sLn=kr&dicQuery=determine&query=determine&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# 역기 결과 내용
# |파파고(번역)
#
#
#
#
#
#
#
#
# determine the ranking
#
# 					미국식
#
#
#
# TTS 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# 순위를 매기다
#
# 중고등학교 교과서 단어
#
#
#
#
# 단어/숙어 더보기
#
#
#
#
# (2,192건)
#
#
#
#
# 정하다
#               			定―
#
#
#
#
#
#
#
#
#
#
# (결정하다) decide, determine; (날짜·장소 등을) fix, set, (formal) appoint; (여럿 중에서 고르다) choose (from/between)
#
#
# 규칙을 정하다
#
#
# make[set up] rules
#
# 예문 TTS 발음듣기
#
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# (결정하다) decide, determine; (날짜·장소 등을) fix, set, (formal) appoint; (여럿 중에서 고르다) choose (from/between)
#
#
#
#
#
#
# 확정
#               			確定
#
#
#
#
#
#
#
#
#
#
# [동사] decide (on/upon), determine, settle, set, fix, confirm, finalize
#
#
# 확정금리로 대출을 받다
#
#
# get[take out] a loan at a fixed interest rate
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 결심1
#               			決心
#
#
#
#
#
#
#
#
#
#
# [명사] (결정) decision, resolution, determination,
# time taken: 1.3606860637664795

# %% [markdown]
# #### 비동기적 방식 (asyncio + aiohttp)
# 하지만, requests모듈은 코루틴으로 만들어진 모듈이 아니기 때문에 위의 코드는 내부적으로 쓰레드를 만들어 동작합니다. 따라서, 요청의 수가 많아질수록 컨텍스트 스위칭의 비용이 발생합니다. 비동기 HTTP통신 라이브러리인 aiohttp를 이용하면 코루틴을 이용한 비동기 방식을 이용할 수 있습니다.

# %%
import time
import asyncio
# aiohttp 설치 필요
import aiohttp
from bs4 import BeautifulSoup


async def get_text_from_url(url):  # 코루틴 정의
    print("Send request to {url}".format(url=url))

    async with aiohttp.ClientSession() as sess:
        async with sess.get(url, headers={'user-agent': 'Mozilla/5.0'}) as res:
            text = await res.text()

    print("Get request to {url}".format(url=url))
    text = BeautifulSoup(text, 'html.parser').text
    print("=" * 150)
    print(text[8000:8300].strip())


async def main():
    base_url = 'https://endic.naver.com/search.nhn?sLn=kr&dicQuery={keyword}&query={keyword}&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N'
    keywords = ['apple', 'banana', 'call', 'feel',
                'hello', 'bye', 'like', 'love', 'environmental',
                'buzz', 'ambition', 'determine']

    # 아직 실행된 것이 아니라, 실행할 것을 계획하는 단계
    futures = [asyncio.ensure_future(get_text_from_url(
        base_url.format(keyword=keyword))) for keyword in keywords]

    await asyncio.gather(*futures)

if __name__ == "__main__":

    start = time.time()
    loop = asyncio.get_event_loop()
    loop.run_until_complete(main())
    end = time.time()
    print("time taken: {}".format(end-start))
# Out:
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=apple&query=apple&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=banana&query=banana&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=call&query=call&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=feel&query=feel&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=hello&query=hello&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=bye&query=bye&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=like&query=like&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=love&query=love&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=environmental&query=environmental&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=buzz&query=buzz&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=ambition&query=ambition&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Send request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=determine&query=determine&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# Get request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=apple&query=apple&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ======================================================================================================================================================
# 사과 하나
#
#
#
#
#
#
#
#
#
# an apple
#
#
#
#
#
#
# 사과나무
#               			沙果나무
#
#
#
#
#
#
#
#
#
#
#
#
#
# apple tree
#
#
#
#
#
#
# 신 사과
#
#
#
#
#
#
#
#
#
# a sour apple
#
#
#
#
#
#
# 애플 파이
#
#
#
#
#
#
#
#
#
# an apple pie
#
#
#
#
#
# 본문 더보기
#
#
#
# (17,812건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# People seem to be a lot like people in the B
# Get request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=bye&query=bye&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ======================================================================================================================================================
# ormal) Goodbye: .
#
#
#
#
#
# 단어/숙어 더보기
#
#
#
#
# (74건)
#
#
#
#
# 안녕
#               			安寧
#
#
#
#
#
#
#
#
#
#
# (인사) (만났을 때) hello, (informal) hi; (헤어질 때) good-bye, (informal) bye
#
#
# 안녕, 나중에 보자
#
#
# See you later.
#
# 예문 TTS 발음듣기
#
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# (인사) (만났을 때) hello, (informa
# Get request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=call&query=call&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ======================================================================================================================================================
# the draft
#
#
# to receive your call-up papers
#
# 예문 TTS 발음듣기
#
#
#
# 소집 명령서를 받다
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# 		                        [명사] (특히 국가 간 경기 출전을 위한) 부름
#
#
#
# 중고등학교 교과서 단어
#
#
#
#
# 단어/숙어 더보기
#
#
#
#
# (2,995건)
#
#
#
#
# 연락
#               			連絡
# Get request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=banana&query=banana&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ======================================================================================================================================================
# ana
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 파초 열매
#
#
#
#
#
#
#
#
#
# a banana
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# a banana
#
#
#
#
#
#
# 바나나 껍질
#
#
#
#
#
#
#
#
#
# a banana peel
#
#
#
#
#
#
# 바나나 껍질을 까다
#
#
#
#
#
#
#
#
#
# peel a banana
#
#
#
#
#
#
# 바나나 껍질을 벗기다
#
#
#
#
#
#
#
#
#
# peel a banana
#
#
#
#
#
# 본문 더보기
#
#
#
# (4,895건)특정 분야의 예문만 보기|이용자 번역 참여하기
#
#
#
# [일반]
# She's slicing a banana
# Get request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=determine&query=determine&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ======================================================================================================================================================
# TTS 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# DET
# (Physiology)
#
# 중고등학교 교과서 단어
#
#
#
#
#
# 자동번역
# 번역기 결과 내용
# |파파고(번역)
#
#
#
#
#
#
#
#
# determine the ranking
#
# 					미국식
#
#
#
# TTS 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# 순위를 매기다
#
# 중고등학교 교과서 단어
#
#
#
#
# 단어/숙어 더보기
#
#
#
#
# (2,192건)
#
#
#
#
# 정하다
# Get request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=buzz&query=buzz&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ======================================================================================================================================================
# 버저를 울리다
#
#
#
#
#
#
#
#
#
# buzz
#
#
#
#
#
#
# 접근 비행하다
#
#
#
#
#
#
#
#
#
# buzz
#
#
#
#
#
#
# 후문2
#               			後聞
#
#
#
#
#
#
#
#
#
#
# (소문) rumor; (확실치 않은) hearsay, (informal) buzz
#
#
# 그가 학교에 장학금을 기증했다는 후문이 돌았다
#
#
# There was a rumor that he had donated scholarship to the school.
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 설2
# Get request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=hello&query=hello&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ======================================================================================================================================================
# 건)
#
#
#
#
# 여보세요
#
#
#
#
#
#
#
#
#
# (전화를 하거나 받을 때) hello
#
#
# 여보세요, 거기 경아네 집이죠?
#
#
# Hello, is this Gyeong-a's house?
#
# 예문 TTS 발음듣기
#
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# (전화를 하거나 받을 때) hello
#
#
#
#
#
#
# 안녕, 오늘 기분이 어때?
#
#
#
#
#
#
#
#
#
# Hello, how are you today?
#
#
#
#
#
#
# 안녕하세요, 예약을 하려 합니다.
#
#
#
#
#
#
#
#
#
# Hello, l'd like to make a reservati
# Get request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=environmental&query=environmental&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ======================================================================================================================================================
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# 환경적 재난
#
# 중고등학교 교과서 단어
#
#
#
#
#
# cause environmental harm
#
# 					미국식
#
#
#
# TTS 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# 환경에 해독을 끼치다
#
# 중고등학교 교과서 단어
#
#
#
#
# 단어/숙어 더보기
#
#
#
#
# (890건)
#
#
#
#
# environ.
#
# 					미국식
#
#
#
# 성우 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣
# Get request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=love&query=love&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ======================================================================================================================================================
# eat you how you wanted to treated. They compliment, they turn your sadness into smiles. They give you a cuddle when you cry and give you advice when you n...
#
#
#
#
#
#
# love-in
#
# 					미국식
#
#
#
# 성우 발음듣기
#
# 					영국식
#
#
#
# TTS 발음듣기
#
#
#
#
#
#
#
#
#
# [명사]
# (구식)
# 러브인(1960년대에 히피들이 주로 갖던 사랑의 집회)
# Get request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=feel&query=feel&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ======================================================================================================================================================
# 다
#
#
#
#
#
#
#
#
#
# (감각·감정 등을) feel, experience
#
#
# 배신감을 느끼다
#
#
# feel betrayed
#
# 예문 TTS 발음듣기
#
#
#
#
# 2 개 뜻 더보기
# 		                    	 :
#
# (감각·감정 등을) feel, experience
#
#
#
#
#
#
# 만지다
#
#
#
#
#
#
#
#
#
# (손으로) touch; (무엇인지 알아내기 위해) feel
#
#
# 어깨를 만지다
#
#
# touch sb on the shoulder
#
# 예문 TTS 발음듣기
#
#
#
#
# 3 개 뜻 더보기
# 		                    	 :
#
# (손으로)
# Get request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=like&query=like&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ======================================================================================================================================================
# ) 같은
# ,
#
# 		                        [부사] 약, 거의
# 		                        ,
#
# 		                        [전치사] …와 같이, …처럼
# ,
#
# 		                        [접속사] …(하)듯이, …같이(as)
# 		                        ,
# Get request to https://endic.naver.com/search.nhn?sLn=kr&dicQuery=ambition&query=ambition&target=endic&ie=utf8&query_utf=&isOnlyViewEE=N
# ======================================================================================================================================================
# 불타는 야망
#
# 중고등학교 교과서 단어
#
#
#
#
# 단어/숙어 더보기
#
#
#
#
# (241건)
#
#
#
#
# 야망
#               			野望
#
#
#
#
#
#
#
#
#
#
# ambition, aspiration
#
#
# 야망을 이루다
#
#
# achieve[fulfill; realize] one's ambition
#
# 예문 TTS 발음듣기
#
#
#
#
#
#
#
# 욕망
#               			慾望
#
#
#
#
#
#
#
#
#
#
# des
# time taken: 1.1499652862548828
